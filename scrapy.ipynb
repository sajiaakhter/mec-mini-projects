# %% [markdown]
# <a href="https://colab.research.google.com/github/sajiaakhter/mec-mini-projects/blob/master/scrapy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scrapy

# %%
import scrapy
import pandas as pd

#to go to my drive to initialize the scrapy project
# %cd "/content/drive/My Drive/Colab Notebooks/"
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
#start new project
# !scrapy startproject scrapy_mini_project
# Out:
# New Scrapy project 'scrapy_mini_project', using template directory '/usr/local/lib/python3.7/dist-packages/scrapy/templates/project', created in:
#     /content/drive/MyDrive/Colab Notebooks/scrapy_mini_project
#
# You can start your first spider with:
#     cd scrapy_mini_project
#     scrapy genspider example example.com

# %%
import scrapy 
from scrapy.linkextractors import LinkExtractor
import pandas as pd
# %cd "scrapy_mini_project"
# !pwd
#run the spider project
# !scrapy crawl quotes

# %%
# !scrapy shell 'http://quotes.toscrape.com/page/1/'

# %%
# %cd "scrapy_mini_project"
# !pwd
# !scrapy crawl toscrape-css -o css-scraper-results.json

# %%
# !pwd
# !scrapy crawl toscrape-xpath -o xpath-scraper-results.json
# Out:
# /content/drive/MyDrive/Colab Notebooks/scrapy_mini_project/scrapy_mini_project
# 2022-03-09 18:48:56 [scrapy.utils.log] INFO: Scrapy 2.6.1 started (bot: scrapy_mini_project)
# 2022-03-09 18:48:56 [scrapy.utils.log] INFO: Versions: lxml 4.2.6.0, libxml2 2.9.8, cssselect 1.1.0, parsel 1.6.0, w3lib 1.22.0, Twisted 22.2.0, Python 3.7.12 (default, Jan 15 2022, 18:48:18) - [GCC 7.5.0], pyOpenSSL 22.0.0 (OpenSSL 1.1.1m  14 Dec 2021), cryptography 36.0.1, Platform Linux-5.4.144+-x86_64-with-Ubuntu-18.04-bionic
# 2022-03-09 18:48:56 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'scrapy_mini_project',
#  'NEWSPIDER_MODULE': 'scrapy_mini_project.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['scrapy_mini_project.spiders']}
# 2022-03-09 18:48:56 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2022-03-09 18:48:56 [scrapy.extensions.telnet] INFO: Telnet Password: 13ebbd703686be47
# ...
