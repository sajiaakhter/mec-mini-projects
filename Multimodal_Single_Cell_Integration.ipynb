# %% [markdown]
# <a href="https://colab.research.google.com/github/sajiaakhter/mec-mini-projects/blob/master/Multimodal_Single_Cell_Integration.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Download Kaggle Data in Colab**

# %%
! pip install -q kaggle

# %%
#before running copy kaggle.json using current APi
! mkdir ~/.kaggle
! cp /kaggle.json ~/.kaggle/
! chmod 600 ~/.kaggle/kaggle.json

# %%
! ls -al /root/.kaggle/
# !kaggle datasets list

# %% [markdown]
# **Downloading Single Cell data**

# %%
# !kaggle competitions download -c open-problems-multimodal
# Out:
# ...
# 100% 18.1G/18.1G [01:41<00:00, 230MB/s]
# 100% 18.1G/18.1G [01:41<00:00, 192MB/s]

# %%
#Unzip data
! unzip /content/open-problems-multimodal.zip
# Out:
# Archive:  /content/open-problems-multimodal.zip
#   inflating: evaluation_ids.csv
#   inflating: metadata.csv
#   inflating: metadata_cite_day_2_donor_27678.csv
#   inflating: sample_submission.csv
#   inflating: test_cite_inputs.h5
#   inflating: test_cite_inputs_day_2_donor_27678.h5
#   inflating: test_multi_inputs.h5
#   inflating: train_cite_inputs.h5
#   inflating: train_cite_targets.h5
#   inflating: train_multi_inputs.h5
#   inflating: train_multi_targets.h5

# %%
#copy data to a directory
# !mkdir /content/open-problems-multimodal
# !mv /content/evaluation_ids.csv /content/open-problems-multimodal
# !mv /content/metadata.csv /content/open-problems-multimodal
# !mv /content/metadata_cite_day_2_donor_27678.csv /content/open-problems-multimodal
# !mv /content/sample_submission.csv /content/open-problems-multimodal
# !mv /content/test_cite_inputs.h5 /content/open-problems-multimodal
# !mv /content/test_cite_inputs_day_2_donor_27678.h5 /content/open-problems-multimodal
# !mv /content/test_multi_inputs.h5 /content/open-problems-multimodal
# !mv /content/train_cite_inputs.h5 /content/open-problems-multimodal
# !mv /content/train_cite_targets.h5 /content/open-problems-multimodal
# !mv /content/train_multi_inputs.h5 /content/open-problems-multimodal
# !mv /content/train_multi_targets.h5 /content/open-problems-multimodal

# %% [markdown]
# **Data Wrangling**

# %%
#import libraries
import numpy as np
import pandas as pd

# %%
evaluation = pd.read_csv('/content/open-problems-multimodal/evaluation_ids.csv')
evaluation.head()
# Out:
#    row_id       cell_id gene_id
# 0       0  c2150f55becb    CD86
# 1       1  c2150f55becb   CD274
# 2       2  c2150f55becb   CD270
# 3       3  c2150f55becb   CD155
# 4       4  c2150f55becb   CD112

# %%
metadata = pd.read_csv('/content/open-problems-multimodal/metadata.csv')
metadata.head(5)
# Out:
#         cell_id  day  donor cell_type technology
# 0  c2150f55becb    2  27678       HSC    citeseq
# 1  65b7edf8a4da    2  27678       HSC    citeseq
# 2  c1b26cb1057b    2  27678      EryP    citeseq
# 3  917168fa6f83    2  27678      NeuP    citeseq
# 4  2b29feeca86d    2  27678      EryP    citeseq

# %%
metadata_donor_27678 = pd.read_csv('/content/open-problems-multimodal/metadata_cite_day_2_donor_27678.csv')
metadata_donor_27678.head(5)
# Out:
#         cell_id  day  donor cell_type technology
# 0  83d6659a6a32    2  27678      NeuP    citeseq
# 1  d98594f13d2e    2  27678      NeuP    citeseq
# 2  5f93d8ffc72f    2  27678      NeuP    citeseq
# 3  7dfa2699d351    2  27678      EryP    citeseq
# 4  6d2533edd0e0    2  27678       HSC    citeseq

# %%
sample_submission = pd.read_csv('/content/open-problems-multimodal/sample_submission.csv')
sample_submission.head(5)
# Out:
#    row_id  target
# 0       0     0.0
# 1       1     0.0
# 2       2     0.0
# 3       3     0.0
# 4       4     0.0

# %%
test_cite_inputs = pd.read_hdf('/content/open-problems-multimodal/test_cite_inputs.h5')
test_cite_inputs.head(5)
# Out:
# gene_id       ENSG00000121410_A1BG  ENSG00000268895_A1BG-AS1  \
# cell_id
# c2150f55becb                   0.0                       0.0
# 65b7edf8a4da                   0.0                       0.0
# c1b26cb1057b                   0.0                       0.0
# 917168fa6f83                   0.0                       0.0
# 2b29feeca86d                   0.0                       0.0
#
# gene_id       ENSG00000175899_A2M  ENSG00000245105_A2M-AS1  \
# cell_id
# c2150f55becb                  0.0                      0.0
# 65b7edf8a4da                  0.0                      0.0
# c1b26cb1057b                  0.0                      0.0
# 917168fa6f83                  0.0                      0.0
# 2b29feeca86d                  0.0                      0.0
#
# gene_id       ENSG00000166535_A2ML1  ENSG00000128274_A4GALT  \
# cell_id
# c2150f55becb                    0.0                0.000000
# 65b7edf8a4da                    0.0                0.000000
# ...

# %%
test_cite_inputs_donor_27678 = pd.read_hdf('/content/open-problems-multimodal/test_cite_inputs_day_2_donor_27678.h5')
test_cite_inputs_donor_27678.head()
# Out:
# gene_ids      ENSG00000121410_A1BG  ENSG00000268895_A1BG-AS1  \
# 83d6659a6a32                   0.0                       0.0
# d98594f13d2e                   0.0                       0.0
# 5f93d8ffc72f                   0.0                       0.0
# 7dfa2699d351                   0.0                       0.0
# 6d2533edd0e0                   0.0                       0.0
#
# gene_ids      ENSG00000175899_A2M  ENSG00000245105_A2M-AS1  \
# 83d6659a6a32                  0.0                 3.131642
# d98594f13d2e                  0.0                 0.000000
# 5f93d8ffc72f                  0.0                 0.000000
# 7dfa2699d351                  0.0                 0.000000
# 6d2533edd0e0                  0.0                 0.000000
#
# gene_ids      ENSG00000166535_A2ML1  ENSG00000128274_A4GALT  \
# 83d6659a6a32                    0.0                     0.0
# d98594f13d2e                    0.0                     0.0
# ...

# %%
 test_multi_inputs = pd.read_hdf('/content/open-problems-multimodal/test_multi_inputs.h5')
 test_multi_inputs.head(5)

# %%
train_cite_inputs= pd.read_hdf('/content/open-problems-multimodal/train_cite_inputs.h5')
train_cite_inputs.head(5)
# Out:
# gene_id       ENSG00000121410_A1BG  ENSG00000268895_A1BG-AS1  \
# cell_id
# 45006fe3e4c8                   0.0                       0.0
# d02759a80ba2                   0.0                       0.0
# c016c6b0efa5                   0.0                       0.0
# ba7f733a4f75                   0.0                       0.0
# fbcf2443ffb2                   0.0                       0.0
#
# gene_id       ENSG00000175899_A2M  ENSG00000245105_A2M-AS1  \
# cell_id
# 45006fe3e4c8                  0.0                      0.0
# d02759a80ba2                  0.0                      0.0
# c016c6b0efa5                  0.0                      0.0
# ba7f733a4f75                  0.0                      0.0
# fbcf2443ffb2                  0.0                      0.0
#
# gene_id       ENSG00000166535_A2ML1  ENSG00000128274_A4GALT  \
# cell_id
# 45006fe3e4c8                    0.0                0.000000
# d02759a80ba2                    0.0                0.000000
# ...

# %%
train_cite_targets= pd.read_hdf('/content/open-problems-multimodal/train_cite_targets.h5')
train_cite_targets.head(5)
# Out:
# gene_id           CD86     CD274     CD270     CD155     CD112      CD47  \
# cell_id
# 45006fe3e4c8  1.167804  0.622530  0.106959  0.324989  3.331674  6.426002
# d02759a80ba2  0.818970  0.506009  1.078682  6.848758  3.524885  5.279456
# c016c6b0efa5 -0.356703 -0.422261 -0.824493  1.137495  0.518924  7.221962
# ba7f733a4f75 -1.201507  0.149115  2.022468  6.021595  7.258670  2.792436
# fbcf2443ffb2 -0.100404  0.697461  0.625836 -0.298404  1.369898  3.254521
#
# gene_id            CD48      CD40     CD154      CD52  ...      CD94  \
# cell_id                                                ...
# 45006fe3e4c8   1.480766 -0.728392 -0.468851 -0.073285  ... -0.448390
# d02759a80ba2   4.930438  2.069372  0.333652 -0.468088  ...  0.323613
# c016c6b0efa5  -0.375034  1.738071  0.142919 -0.971460  ...  1.348692
# ba7f733a4f75  21.708519 -0.137913  1.649969 -0.754680  ...  1.504426
# fbcf2443ffb2  -1.659380  0.643531  0.902710  1.291877  ...  0.777023
#
# ...

# %%
train_multi_inputs= pd.read_hdf('/content/open-problems-multimodal/train_multi_inputs.h5')
train_multi_inputs.head(5)

# %%
train_multi_targets= pd.read_hdf('/content/open-problems-multimodal/train_multi_targets.h5')
train_multi_targets.head(5)
# Out:
# gene_id       ENSG00000121410  ENSG00000268895  ENSG00000175899  \
# cell_id
# 56390cf1b95e              0.0         0.000000              0.0
# fc0c60183c33              0.0         0.000000              0.0
# 9b4a87e22ad0              0.0         0.000000              0.0
# 81cccad8cd81              0.0         4.507936              0.0
# 15cb3d85c232              0.0         0.000000              0.0
#
# gene_id       ENSG00000245105  ENSG00000166535  ENSG00000256661  \
# cell_id
# 56390cf1b95e              0.0              0.0              0.0
# fc0c60183c33              0.0              0.0              0.0
# 9b4a87e22ad0              0.0              0.0              0.0
# 81cccad8cd81              0.0              0.0              0.0
# 15cb3d85c232              0.0              0.0              0.0
#
# gene_id       ENSG00000184389  ENSG00000128274  ENSG00000094914  \
# cell_id
# 56390cf1b95e              0.0              0.0              0.0
# ...
